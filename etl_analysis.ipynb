# %%
from supabase import create_client,client
from dotenv import load_dotenv
import pandas as pd,os


load_dotenv()
supabase = create_client(os.getenv("SUPABASE_URL"),os.getenv("SUPABASE_KEY"))
data = supabase.table("titanic_data").select("*").execute()
df = pd.DataFrame(data.data)
df.head()
df.info()
df.isnull().sum()
df.describe()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   sex          891 non-null    object
#  4   age          891 non-null    float64
#  5   sibsp        891 non-null    int64
#  6   parch        891 non-null    int64
#  7   fare         891 non-null    float64
#  8   embarked     891 non-null    object
#  9   class        891 non-null    object
#  10  who          891 non-null    object
#  11  deck         891 non-null    object
#  12  embark_town  889 non-null    object
#  13  alone        891 non-null    bool
#  14  family_size  891 non-null    int64
#  15  is_alone     891 non-null    bool
#  16  title        891 non-null    object
# dtypes: bool(2), float64(2), int64(6), object(7)
# memory usage: 106.3+ KB
# Index(['id', 'survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'deck', 'embark_town', 'alone',
#        'family_size', 'is_alone', 'title'],
#       dtype='object')

# %%
# !pip install supabase
# Out:
# Collecting supabase
#   Downloading supabase-2.25.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting realtime==2.25.0 (from supabase)
#   Downloading realtime-2.25.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting supabase-functions==2.25.0 (from supabase)
#   Downloading supabase_functions-2.25.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting storage3==2.25.0 (from supabase)
#   Downloading storage3-2.25.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting supabase-auth==2.25.0 (from supabase)
#   Downloading supabase_auth-2.25.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting postgrest==2.25.0 (from supabase)
#   Downloading postgrest-2.25.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: httpx<0.29,>=0.26 in c:\users\trisha\anaconda3\lib\site-packages (from supabase) (0.27.0)
# Collecting deprecation>=2.1.0 (from postgrest==2.25.0->supabase)
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pydantic<3.0,>=1.9 in c:\users\trisha\anaconda3\lib\site-packages (from postgrest==2.25.0->supabase) (2.8.2)
# Collecting yarl>=1.20.1 (from postgrest==2.25.0->supabase)
#   Downloading yarl-1.22.0-cp312-cp312-win_amd64.whl.metadata (77 kB)
# Collecting pydantic<3.0,>=1.9 (from postgrest==2.25.0->supabase)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting typing-extensions>=4.14.0 (from realtime==2.25.0->supabase)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting websockets<16,>=11 (from realtime==2.25.0->supabase)
#   Using cached websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Collecting pyjwt>=2.10.1 (from pyjwt[crypto]>=2.10.1->supabase-auth==2.25.0->supabase)
#   Using cached PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting strenum>=0.4.15 (from supabase-functions==2.25.0->supabase)
#   Using cached StrEnum-0.4.15-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: anyio in c:\users\trisha\anaconda3\lib\site-packages (from httpx<0.29,>=0.26->supabase) (4.2.0)
# Requirement already satisfied: certifi in c:\users\trisha\anaconda3\lib\site-packages (from httpx<0.29,>=0.26->supabase) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\trisha\anaconda3\lib\site-packages (from httpx<0.29,>=0.26->supabase) (1.0.2)
# Requirement already satisfied: idna in c:\users\trisha\anaconda3\lib\site-packages (from httpx<0.29,>=0.26->supabase) (3.7)
# Requirement already satisfied: sniffio in c:\users\trisha\anaconda3\lib\site-packages (from httpx<0.29,>=0.26->supabase) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\trisha\anaconda3\lib\site-packages (from httpcore==1.*->httpx<0.29,>=0.26->supabase) (0.14.0)
# Requirement already satisfied: packaging in c:\users\trisha\anaconda3\lib\site-packages (from deprecation>=2.1.0->postgrest==2.25.0->supabase) (24.1)
# Collecting h2<5,>=3 (from httpx[http2]<0.29,>=0.26->postgrest==2.25.0->supabase)
#   Using cached h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\trisha\anaconda3\lib\site-packages (from pydantic<3.0,>=1.9->postgrest==2.25.0->supabase) (0.6.0)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0,>=1.9->postgrest==2.25.0->supabase)
#   Downloading pydantic_core-2.41.5-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0,>=1.9->postgrest==2.25.0->supabase)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\trisha\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.25.0->supabase) (43.0.0)
# Requirement already satisfied: multidict>=4.0 in c:\users\trisha\anaconda3\lib\site-packages (from yarl>=1.20.1->postgrest==2.25.0->supabase) (6.0.4)
# Collecting propcache>=0.2.1 (from yarl>=1.20.1->postgrest==2.25.0->supabase)
#   Downloading propcache-0.4.1-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: cffi>=1.12 in c:\users\trisha\anaconda3\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.25.0->supabase) (1.17.1)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.25.0->supabase)
#   Using cached hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.25.0->supabase)
#   Using cached hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pycparser in c:\users\trisha\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.25.0->supabase) (2.21)
# Downloading supabase-2.25.0-py3-none-any.whl (16 kB)
# Downloading postgrest-2.25.0-py3-none-any.whl (21 kB)
# Downloading realtime-2.25.0-py3-none-any.whl (22 kB)
# Downloading storage3-2.25.0-py3-none-any.whl (26 kB)
# Downloading supabase_auth-2.25.0-py3-none-any.whl (48 kB)
# Downloading supabase_functions-2.25.0-py3-none-any.whl (8.5 kB)
# Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------ --- 1.8/2.0 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 5.4 MB/s eta 0:00:00
# Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Using cached StrEnum-0.4.15-py3-none-any.whl (8.9 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached websockets-15.0.1-cp312-cp312-win_amd64.whl (176 kB)
# Downloading yarl-1.22.0-cp312-cp312-win_amd64.whl (87 kB)
# Using cached h2-4.3.0-py3-none-any.whl (61 kB)
# Downloading propcache-0.4.1-cp312-cp312-win_amd64.whl (41 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached hpack-4.1.0-py3-none-any.whl (34 kB)
# Using cached hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Installing collected packages: strenum, websockets, typing-extensions, pyjwt, propcache, hyperframe, hpack, deprecation, yarl, typing-inspection, pydantic-core, h2, pydantic, supabase-functions, supabase-auth, storage3, realtime, postgrest, supabase
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.8.0
#     Uninstalling PyJWT-2.8.0:
#       Successfully uninstalled PyJWT-2.8.0
#   Attempting uninstall: yarl
#     Found existing installation: yarl 1.11.0
#     Uninstalling yarl-1.11.0:
#       Successfully uninstalled yarl-1.11.0
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.20.1
#     Uninstalling pydantic_core-2.20.1:
#       Successfully uninstalled pydantic_core-2.20.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.8.2
#     Uninstalling pydantic-2.8.2:
#       Successfully uninstalled pydantic-2.8.2
# Successfully installed deprecation-2.1.0 h2-4.3.0 hpack-4.1.0 hyperframe-6.1.0 postgrest-2.25.0 propcache-0.4.1 pydantic-2.12.5 pydantic-core-2.41.5 pyjwt-2.10.1 realtime-2.25.0 storage3-2.25.0 strenum-0.4.15 supabase-2.25.0 supabase-auth-2.25.0 supabase-functions-2.25.0 typing-extensions-4.15.0 typing-inspection-0.4.2 websockets-15.0.1 yarl-1.22.0

# %%
df.columns
# Out:
# Index(['id', 'survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'deck', 'embark_town', 'alone',
#        'family_size', 'is_alone', 'title'],
#       dtype='object')

# %%
df['family_size']
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      1
#       ..
# 886    1
# 887    1
# 888    4
# 889    1
# 890    1
# Name: family_size, Length: 891, dtype: int64

# %%
df['family_size'][0] = 3
# Out:
# C:\Users\trisha\AppData\Local\Temp\ipykernel_41524\1563708787.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['family_size'][0] = 3
